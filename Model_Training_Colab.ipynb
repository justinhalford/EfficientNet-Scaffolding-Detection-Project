# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install transformers
# !pip install torchvision
# !pip install timm
# Out:
# Collecting transformers
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 34.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 80.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 38.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.1.0+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.0->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.0->torchvision) (1.3.0)
# Collecting timm
#   Downloading timm-0.9.8-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.16.0+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.17.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: timm
# Successfully installed timm-0.9.8

# %%
# !unzip "/content/drive/MyDrive/cv_dataset.zip" -d "/content/cv_dataset"
# Out:
# Archive:  /content/drive/MyDrive/cv_dataset.zip
#    creating: /content/cv_dataset/cv_dataset/
#   inflating: /content/cv_dataset/__MACOSX/._cv_dataset
#   inflating: /content/cv_dataset/cv_dataset/.DS_Store
#   inflating: /content/cv_dataset/__MACOSX/cv_dataset/._.DS_Store
#    creating: /content/cv_dataset/cv_dataset/yes_scaffolding/
#    creating: /content/cv_dataset/cv_dataset/no_scaffolding/
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00257.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00243.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00055.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00041.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00069.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00096.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00082.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00121.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00135.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00109.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00108.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00134.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00120.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00083.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00097.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00068.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00040.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00054.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00242.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00256.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00240.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00254.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00268.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00042.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00056.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00081.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00095.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00136.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00122.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00123.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00137.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00094.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00080.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00057.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00043.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00269.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00255.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00241.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00245.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00251.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00047.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00053.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00084.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00090.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00133.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00127.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/.DS_Store
#   inflating: /content/cv_dataset/__MACOSX/cv_dataset/yes_scaffolding/._.DS_Store
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00126.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00132.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00091.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00085.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00052.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00046.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00250.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00244.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00252.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00246.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00078.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00050.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00044.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00093.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00087.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00118.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00124.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00130.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00131.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00125.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00119.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00086.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00092.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00045.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00051.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00079.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00247.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00253.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00234.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00220.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00036.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00022.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00023.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00037.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00221.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00235.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00223.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00237.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00021.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00035.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00009.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00008.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00034.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00020.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00236.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00222.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00226.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00232.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00018.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00024.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00030.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00031.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00025.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00019.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00233.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00227.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00219.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00231.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00225.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00033.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00027.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00026.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00032.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00224.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00230.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00218.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00215.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00229.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00017.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00003.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00002.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00016.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00228.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00214.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00216.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00014.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00028.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00029.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00015.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00001.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00217.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00213.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00039.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00005.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00011.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00010.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00004.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00038.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00212.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00238.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00210.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00012.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00006.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00007.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00013.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00211.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00239.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00262.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00074.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00060.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00048.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00100.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00114.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00128.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00129.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00115.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00101.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00049.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00061.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00075.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00263.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00261.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00249.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00063.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00077.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00088.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00117.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00103.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00102.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00116.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00089.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00076.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00062.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00248.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00260.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00258.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00264.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00270.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00066.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00072.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00099.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00112.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00106.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00107.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00113.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00098.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00073.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00067.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00271.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00265.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00259.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00267.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00059.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00071.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00065.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00139.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00105.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00111.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00110.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00104.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00138.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00064.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00070.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00058.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00266.png
#   inflating: /content/cv_dataset/cv_dataset/yes_scaffolding/yes_scaffolding00272.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00097.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00083.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00054.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00040.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00068.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00120.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00134.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00108.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00109.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00135.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00121.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00069.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00041.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00055.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00082.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00096.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00080.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00094.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00043.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00057.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00137.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00123.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00122.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00136.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00056.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00042.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00095.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00081.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00085.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00091.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00046.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00052.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/.DS_Store
#   inflating: /content/cv_dataset/__MACOSX/cv_dataset/no_scaffolding/._.DS_Store
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00132.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00126.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00127.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00133.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00053.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00047.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00090.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00084.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00092.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00086.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00079.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00051.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00045.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00119.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00125.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00131.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00130.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00124.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00118.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00044.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00050.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00078.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00087.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00093.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00037.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00023.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00209.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00180.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00194.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00143.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00157.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00156.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00142.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00195.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00181.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00208.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00022.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00036.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00020.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00034.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00008.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00197.png
#   inflating: /content/cv_dataset/__MACOSX/cv_dataset/no_scaffolding/._no_scaffolding00197.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00183.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00154.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00140.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00168.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00169.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00141.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00155.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00182.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00196.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00009.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00035.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00021.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00019.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00025.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00031.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00192.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00186.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00179.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00151.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00145.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00144.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00150.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00178.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00187.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00193.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00030.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00024.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00018.png
#   inflating: /content/cv_dataset/__MACOSX/cv_dataset/no_scaffolding/._no_scaffolding00018.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00032.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00026.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00185.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00191.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00146.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00152.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00153.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00147.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00190.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00184.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00027.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00033.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00016.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00002.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00189.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00162.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00176.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00177.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00163.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00188.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00003.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00017.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00001.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00015.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00029.png
#   inflating: /content/cv_dataset/__MACOSX/cv_dataset/no_scaffolding/._no_scaffolding00029.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00203.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00175.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00161.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00149.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00148.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00160.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00174.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00202.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00028.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00014.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00038.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00004.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00010.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00206.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00158.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00170.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00164.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00165.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00171.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00159.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00207.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00011.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00005.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00039.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00013.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00007.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00205.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00167.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00173.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00172.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00166.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00204.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00006.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00012.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00075.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00061.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00049.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00101.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00115.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00129.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00128.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00114.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00100.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00048.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00060.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00074.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00089.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00062.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00076.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00116.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00102.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00103.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00117.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00077.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00063.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00088.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00098.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00067.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00073.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00113.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00107.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00106.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00112.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00072.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00066.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00099.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00058.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00070.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00064.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00138.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00104.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00110.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00111.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00105.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00139.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00065.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00071.png
#   inflating: /content/cv_dataset/cv_dataset/no_scaffolding/no_scaffolding00059.png

# %%
import torch
import torchvision
from torchvision import transforms, datasets
import timm
from torch import nn, optim

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
    ]),
}

main_dir = '/content/cv_dataset/cv_dataset'
dataset = datasets.ImageFolder(main_dir, transform=data_transforms['train'])

# Splitting dataset into training and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])


train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
# EfficientNet model
model = timm.create_model("efficientnet_b3", pretrained=True, num_classes=1)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=2.12e-3)

# Training
num_epochs = 5
for epoch in range(num_epochs):
    model.train()
    total_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs.view(-1), labels.float())

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {total_loss/len(train_loader)}")
# Out:
# Epoch 1/5, Loss: 2.8737454059578122
# Epoch 2/5, Loss: 1.1625414285677143
# Epoch 3/5, Loss: 0.41371855461260393
# Epoch 4/5, Loss: 0.3174331374466419
# Epoch 5/5, Loss: 0.1481312752834388

# %%
# Calculate accuracy
def binary_accuracy(preds, y):
    """
    Returns accuracy per batch
    """
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float()
    acc = correct.sum() / len(correct)
    return acc

model.eval()

total_loss, total_acc = 0, 0

with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)

        loss = criterion(outputs.view(-1), labels.float())

        acc = binary_accuracy(outputs.view(-1), labels.float())

        total_loss += loss.item()
        total_acc += acc.item()

# Overall average loss and accuracy
avg_loss = total_loss / len(val_loader)
avg_acc = total_acc / len(val_loader)

print(f"Validation Loss: {avg_loss:.4f}")
print(f"Validation Accuracy: {avg_acc*100:.2f}%")

import os

# Ensure the 'Good models' directory exists
if not os.path.exists('Good models'):
    os.makedirs('Good models')

# Function to get the next available model index
def get_next_model_index(directory):
    existing_files = os.listdir(directory)
    existing_indices = [int(f.split('_')[-1].split('.')[0]) for f in existing_files if f.startswith('model_') and f.endswith('.pth')]
    if existing_indices:
        return max(existing_indices) + 1
    return 1  # Return 1 if no existing models

# Check the accuracy
if avg_acc * 100 > 90:
    next_index = get_next_model_index('Good models')
    model_path = os.path.join('Good models', f'model_{next_index}.pth')
    torch.save(model.state_dict(), model_path)
    print(f"Model saved as {model_path}")
# Out:
# Validation Loss: 0.0981
# Validation Accuracy: 96.88%
# Model saved as Good models/model_5.pth

# %%
import os
import numpy as np
from PIL import Image

root_dir = 'predictions'
sub_dirs = ['correct_yes', 'correct_no', 'incorrect_yes', 'incorrect_no']
for sub_dir in sub_dirs:
    os.makedirs(os.path.join(root_dir, sub_dir), exist_ok=True)

model.eval()

counters = {sub_dir: 0 for sub_dir in sub_dirs}
correct_yes, correct_no, incorrect_yes, incorrect_no = 0, 0, 0, 0

with torch.no_grad():
    for image, label in val_dataset:
        image_tensor = image.unsqueeze(0).to(device)

        output = model(image_tensor)
        predicted = torch.sigmoid(output).item() > 0.5

        if label == 1 and predicted:
            correct_yes += 1
            folder = 'correct_yes'
        elif label == 0 and not predicted:
            correct_no += 1
            folder = 'correct_no'
        elif label == 1 and not predicted:
            incorrect_no += 1
            folder = 'incorrect_no'
        else:
            incorrect_yes += 1
            folder = 'incorrect_yes'

        counters[folder] += 1
        img_name = f"{folder}_{counters[folder]:03}.png"
        path = os.path.join(root_dir, folder, img_name)
        Image.fromarray((image.numpy().transpose(1, 2, 0) * 255).astype(np.uint8)).save(path)

total = len(val_dataset)

yes_accuracy = (correct_yes / (correct_yes + incorrect_yes)) * 100
no_accuracy = (correct_no / (correct_no + incorrect_no)) * 100

with open(os.path.join(root_dir, 'metrics.txt'), 'w') as file:
    file.write(f"Yes Accuracy: {yes_accuracy:.2f}%\n")
    file.write(f"No Accuracy: {no_accuracy:.2f}%\n")

# %%
PATH = "trained_model.pth"

torch.save(model.state_dict(), PATH)

print(f"Model's state_dict saved to {PATH}")
# Out:
# Model's state_dict saved to trained_model.pth

# %%
import os
import numpy as np
from PIL import Image
import torch

# Function to load all saved models from the 'Good models' directory
def load_saved_models(directory, device):
    model_paths = [os.path.join(directory, fname) for fname in os.listdir(directory) if fname.endswith('.pth')]
    models = []
    for model_path in model_paths:
        model_instance = timm.create_model("efficientnet_b3", pretrained=False, num_classes=1).to(device)
        model_instance.load_state_dict(torch.load(model_path))
        model_instance.eval()
        models.append(model_instance)
    return models

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
models = load_saved_models('Good models', device)

root_dir = 'predictions'
sub_dirs = ['correct_yes', 'correct_no', 'incorrect_yes', 'incorrect_no']
for sub_dir in sub_dirs:
    os.makedirs(os.path.join(root_dir, sub_dir), exist_ok=True)

counters = {sub_dir: 0 for sub_dir in sub_dirs}
correct_yes, correct_no, incorrect_yes, incorrect_no = 0, 0, 0, 0

with torch.no_grad():
    for image, label in val_dataset:
        image_tensor = image.unsqueeze(0).to(device)
        predictions = []

        # Collect predictions from all models
        for model in models:
            output = model(image_tensor)
            predicted = torch.sigmoid(output).item() > 0.5
            predictions.append(predicted)

        # Requiring consensus among at least 5 of 5 models
        if predictions.count(True) >= 5:
            consensus_prediction = 1
        else:
            consensus_prediction = 0

        if label == 1 and consensus_prediction:
            correct_yes += 1
            folder = 'correct_yes'
        elif label == 0 and not consensus_prediction:
            correct_no += 1
            folder = 'correct_no'
        elif label == 1 and not consensus_prediction:
            incorrect_no += 1
            folder = 'incorrect_no'
        else:
            incorrect_yes += 1
            folder = 'incorrect_yes'

        counters[folder] += 1
        img_name = f"{folder}_{counters[folder]:03}.png"
        path = os.path.join(root_dir, folder, img_name)
        Image.fromarray((image.numpy().transpose(1, 2, 0) * 255).astype(np.uint8)).save(path)

total = len(val_dataset)

yes_accuracy = (correct_yes / (correct_yes + incorrect_yes)) * 100
no_accuracy = (correct_no / (correct_no + incorrect_no)) * 100

with open(os.path.join(root_dir, 'metrics.txt'), 'w') as file:
    file.write(f"Yes Accuracy: {yes_accuracy:.2f}%\n")
    file.write(f"No Accuracy: {no_accuracy:.2f}%\n")

print(f"True Positives: {correct_yes}")
print(f"True Negatives: {correct_no}")
print(f"False Positives: {incorrect_yes}")
print(f"False Negatives: {incorrect_no}")
# Out:
# True Positives: 32
# True Negatives: 40
# False Positives: 0
# False Negatives: 10
